# %% [markdown]
# Q.1) What is python? How would you explain its key features and characteristics?

# %% [markdown]
# Python is high level programming language close to the human language.It is used in wide applications like Data Science,Web development etc.
# It is beginner friendly as it offers simple syntax which makes it easily readable.It includes different libraries such as Numpy,Pandas,Matplotlib,
# Scikit-learn.

# %% [markdown]
# Features of Python:
#   1.Easy to learn and Use: As it offers simple syntax it is easy to learn and use.It uses English like keywords like
#     'from','in','as','or','and'.
#   2.Dynamically Typed language: Python automatically identifies datatypes of variables while executing the code.It helps
#     to speed up development.
#   3.Free and Open source: Python is free to use and distributions and its source code is open,allow for community
#     distibution and modification
#   4.Interpreted laungauge: Python code is executed line by line by an interprted.This feature offers rapid development and
#     debugging,as changes can be tested immediatly

# %% [markdown]
# Characteristics of Python:
#   1.Simplicity and Readability: Python includes simple and concise syntax often resembling natural language. Python use of
#     intendation for code block enhances readability and makes it esier to learn and use
#   2.High level language:It is high level language close to human language. As it close to human language it is easy to learn
#     and understand.It helps developers to focus on problem-solving rather than system specific
#   3.Free and Open Source: Python is freely available and its source code is open for modification and distribution.It allows      community to modification and distribution.

# %% [markdown]
# Q.2)List and Explain some common applications of Python

# %% [markdown]
#    Pyhton used in widely applications as its verstile programming language.Some application as follows:

# %% [markdown]
# 1.Web Development: Python is widely used for building web application and services. It occurs some frameworks like Django and
#   flaskfor creating dynamic websites.
# 2.Data Science and Analysis: Python is a favorite for working with data.Libraries like Pandas and NumPy help organize, clean,
#   and analyze largedatasets,while libraries that offers by python like Matplotlib and Seaborn allow for creating clear
#   visualizations to understand the data better.
# 3.Artificial Intelligence (AI) and Machine Learning (ML): Python is core language to build Al and ML models.Libraries such as   TensorFlow and PyTorch  helps in the creation of intelligent systems that can learn from data, like image recognition,
#   natural language processing(NLP).
# 4.Software Development: Python is used for software development, from creating simple command-line tools to building more
#   complex desktop applications with graphical user interfaces (GUIs) using specific libraries.
# 5.Game Development:Python does not use for high-wend game.Python is used in game development for creating smaller,
#   independent games with libraries like Pygame.

# %% [markdown]
# Q.3) Discuss the advantages and disadvantages of using python as programming language.

# %% [markdown]
#  Advantages:

# %% [markdown]
#     1.Easy to Learn and Use: Python's syntax is simple and close to natural language, making it easy for beginners to
#       learn and write code quickly.
#     2.Versatility: Python can be used for a wide range of applications, including web development, data analysis, artificial
#       intelligence, machine learning.
#     3.Readability: Python's clear and well orgnized code structure makes it easier to read, understand, and maintain
#       specially in collaborative
#       projects.
#     4.Large number of Libraries: Python has a large number of of pre-built libraries and frameworks like NumPy, Pandas,
#       Django, Flask that simplify development and save time while programming.

# %% [markdown]
#    Disadvantages:

# %% [markdown]
#     1.Slower Speed: Being an interpreted language, Python can be slower than compiled languages like C++ for tasks
#       requiring high performance.
#     2.Higher memory Consumption: Python can be more memory cumsumer compared to some other languages, which might be a
#       problem for applications which has limited memory resources.
#     3.Not Ideal for mobile Development: Python can be use in backend services hence it's generally not the choice for
#       respective mobile application development.
#     4.Runtime Errors: Due to its dynamic typing, some errors might only appear during program
#       execution whilw its writing.It requires to go through the testing.
