# %% [markdown]
# # Q.1.a) Create a text file named "sample.txt" with the content "Hello, File Handling!". Write a Python program to open the file, read its content, and print it. Now, count the number of words in the file. Print the word count.

# %%
with open("sample.txt",'w') as file:
    file.write("Hello, File Handling!")
with open("sample.txt",'r') as file:
    content=file.read()
    print(f"File content:",content)
words=content.split()
word_count=len(words)
print(f"Word count:",word_count)
# Out:
# File content: Hello, File Handling!
# Word count: 3

# %% [markdown]
# ##
# ------
# ##

# %% [markdown]
# # Q.2. a) Write a Python program to create a new text file named "output.txt" and write three lines of text into the file.
# # b) Append a new line of text to the existing "output.txt" file created in the previous problem.

# %%
with open("output.txt",'w') as file:
    file.write("Hello, File Handling!.\nPython is great.\nNow i am practising.")

# %%
with open("output.txt",'r') as file:
    content=file.read()
    print(content)
# Out:
# Hello, File Handling!.
# Python is great.
# Now i am practising.
# I am getting this

# %%
with open("output.txt",'a') as file:
    file.write("\nI am getting this")

# %% [markdown]
# ##
# -----
# ##

# %% [markdown]
# # Q.3.a) Create a text file named "numbers.txt" with numbers 1 to 5 each on a new line. Write a Python program to open the file, read its content line by line, and print each line.
# # b) Write a Python program to read the content of "numbers.txt" and create a new file named   "numbers_copy.txt" with the same content.

# %%
with open("numbers.txt",'w') as file:
    file.write('\n1\n2\n3\n4\n5')

# %%
with open("numbers.txt",'r') as file:
    content=file.read()
    print(content)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
with open("numbers.txt",'r') as oroginal, open("numbers_copy.txt",'w') as copy:
    copy.write('\n1\n2\n3\n4\n5')

# %%
with open("numbers_copy.txt",'r') as copy:
    content=copy.read()
    print(content)
# Out:
# 1
# 2
# 3
# 4
# 5
